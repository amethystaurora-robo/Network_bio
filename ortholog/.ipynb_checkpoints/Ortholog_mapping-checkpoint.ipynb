# %%
import pandas as pd
import numpy as np
import re

# %%
fruit_fly = pd.read_csv('magna_melanogaster.tsv',sep='\t')
human = pd.read_csv('dma_hsa.tsv',sep='\t')
daphnia_pulex = pd.read_csv('dma_dpx.tsv',sep='\t')
dosed_genes = pd.read_csv('../omics/dosed_genes.csv')
protein_info = pd.read_csv('enzyme_proteins.csv')
kegg_terms = pd.read_csv('../GRN/DynGENIE3/user_ko.tsv',sep="\t")

# %%
#create a file which combines all 3 ortholog mappings in 4 columns - magna, pulex, fruit fly, human, titled human_daphnia
fly_human = pd.merge(fruit_fly, human, on='Daphnia_magna')
human_daphnia = pd.merge(fly_human, daphnia_pulex, on='Daphnia_magna')

# %%
human_daphnia.to_csv('all_orthologs.csv')

# %%
#clean Dapma column in KEGG terms file
kegg_terms['regulatory'] = kegg_terms['regulatory'].str.replace('t1$', '', regex=True)
#merge protein information with KEGG terms
kegg_protein = pd.merge(kegg_terms,protein_info,on='KO')
print(len(kegg_protein['KO'].unique()))
print(kegg_protein['KO'].unique())
kegg_protein.head()
kegg_protein.to_csv('protein_info_kegg_terms.csv')
# Out:
# 141
# ['K04374' 'K09028' 'K09035' 'K09382' 'K08031' 'K09173' 'K09448' 'K23195'
#  'K04491' 'K24889' 'K11224' 'K24637' 'K08705' 'K08544' 'K09067' 'K09090'
#  'K16672' 'K02678' 'K17696' 'K09381' 'K09057' 'K09414' 'K14034' 'K10180'
#  'K09231' 'K09364' 'K09355' 'K25856' 'K08035' 'K22536' 'K15603' 'K09385'
#  'K16796' 'K09267' 'K09407' 'K09070' 'K09228' 'K09427' 'K05870' 'K07466'
#  'K08066' 'K00558' 'K21626' 'K15607' 'K09366' 'K09201' 'K08064' 'K09339'
#  'K09276' 'K08704' 'K04453' 'K14032' 'K24369' 'K05706' 'K09225' 'K09377'
#  'K06053' 'K03120' 'K09031' 'K08065' 'K09319' 'K09191' 'K09073' 'K09313'
#  'K08546' 'K09370' 'K08539' 'K09275' 'K17845' 'K15690' 'K09219' 'K15605'
#  'K25794' 'K09272' 'K14960' 'K09273' 'K22758' 'K04448' 'K04683' 'K08703'
#  'K11660' 'K09214' 'K09332' 'K07295' 'K24874' 'K09324' 'K09371' 'K09180'
#  'K09404' 'K24895' 'K04682' 'K09373' 'K09441' 'K09375' 'K15263' 'K09389'
#  'K09256' 'K09200' 'K09257' 'K21772' 'K11308' 'K09103' 'K09081' 'K09372'
#  'K08268' 'K09037' 'K09260' 'K04734' 'K10185' 'K14035' 'K18486' 'K26434'
#  'K08545' 'K09097' 'K09098' 'K24768' 'K09106' 'K22870' 'K11307' 'K09374'
#  'K11304' 'K15614' 'K11485' 'K23407' 'K24387' 'K10779' 'K08362' 'K09307'
#  'K02296' 'K09208' 'K09100' 'K04681' 'K09199' 'K09114' 'K09113' 'K07197'
#  'K15608' 'K24645' 'K09436' 'K17398' 'K25793']

# %%
#merge protein information with differentially expressed genes
proteins_dosed_genes = pd.merge(kegg_protein,dosed_genes,on='regulatory')
print(len(proteins_dosed_genes))
print(proteins_dosed_genes['KO'].notna().sum())
print(proteins_dosed_genes['KO'].unique())
proteins_dosed_genes.head()
# Out:
# 11881
# 11881
# ['K24889']
#          regulatory      KO                                  Description  \
# 0  Dapma7bEVm009954  K24889  IRX; iroquois-class homeodomain protein IRX
# 1  Dapma7bEVm009954  K24889  IRX; iroquois-class homeodomain protein IRX
# 2  Dapma7bEVm009954  K24889  IRX; iroquois-class homeodomain protein IRX
# 3  Dapma7bEVm009954  K24889  IRX; iroquois-class homeodomain protein IRX
# 4  Dapma7bEVm009954  K24889  IRX; iroquois-class homeodomain protein IRX
#
#   Functional_Hier_A Functional_Hier_B  Functional_Hier_C  Unnamed: 0  \
# 0   Eukaryotic type  Helix-turn-helix  Homeo domain TALE          14
# 1   Eukaryotic type  Helix-turn-helix  Homeo domain TALE          89
# 2   Eukaryotic type  Helix-turn-helix  Homeo domain TALE         164
# 3   Eukaryotic type  Helix-turn-helix  Homeo domain TALE         239
# 4   Eukaryotic type  Helix-turn-helix  Homeo domain TALE         314
#
#              target  X.1.x       x.x  X.x  weight.x  out.degree.x  \
# 0  Dapma7bEVm004153    134  0.132691   79  0.004791     82.472342
# 1  Dapma7bEVm004154    651  0.132691   79  0.003884     82.472342
# 2  Dapma7bEVm004155   1283  0.132691   79  0.012151     82.472342
# 3  Dapma7bEVm004156   1707  0.132691   79  0.018067     82.472342
# 4  Dapma7bEVm004157   1920  0.132691   79  0.004333     82.472342
#
#    in.degree.x  X.1.y       x.y  X.y  weight.y  out.degree.y  in.degree.y
# 0     0.051466    286  0.116999   79  0.006024    151.432883     0.022780
# 1     0.030319    673  0.116999   79  0.007474    151.432883     0.032943
# 2     0.049909   1115  0.116999   79  0.011421    151.432883     0.022752
# 3     0.086413   2000  0.116999   79  0.001037    151.432883     0.067550
# 4     0.035515   2387  0.116999   79  0.006069    151.432883     0.006949

# %%
print(proteins_dosed_genes['regulatory'].unique())
# Out:
# ['Dapma7bEVm009954']
